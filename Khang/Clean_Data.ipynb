# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn

# %%
df = pd.read_csv('raw_data.csv')

# %%
df
# Out:
#                                                  Address     Prices     Area
# 0       Đường Hà Mục, Phường Hòa Thọ Đông, Quận Cẩm L...   5,15 tỷ    100 m2  \
# 1       Đường Thi Sách, Phường Hòa Thuận Tây, Quận Hả...    4,1 tỷ     85 m2
# 2       Đường Ông Ích Khiêm, Phường Tam Thuận, Quận T...     11 tỷ     67 m2
# 3       Đường Núi Thành, Phường Hòa Cường Bắc, Quận H...   17,5 tỷ    137 m2
# 4       Đường Trương Văn Hiến, Phường Khuê Mỹ, Quận N...      7 tỷ     90 m2
# ...                                                  ...        ...      ...
# 14936   Đường Nguyễn Thị Định, Phường An Hải Bắc, Quậ...    9,5 tỷ     90 m2
# 14937   300/22 Đường Hải Phòng, Phường Hải Châu I, Qu...   2,85 tỷ     50 m2
# 14938   Đường Ông Ích Khiêm, Phường Thanh Bình, Quận ...   4,35 tỷ     57 m2
# 14939   K814A/52 Đường Trần Cao Vân, Phường Thanh Khê...   3,35 tỷ     52 m2
# 14940   Đường Hoàng Văn Thái, Phường Hòa Khánh Nam, Q...   2,99 tỷ     70 m2
#
# ...

# %%
df[(df['toFace']=='_')]
# Out:
#                                                  Address     Prices     Area
# 1       Đường Thi Sách, Phường Hòa Thuận Tây, Quận Hả...    4,1 tỷ     85 m2  \
# 5       Đường Nguyễn Văn Thoại, Phường An Hải Đông, Q...     26 tỷ    154 m2
# 6       Đường Hóa Quê Trung, Phường Hòa Cường Bắc, Qu...    5,4 tỷ    100 m2
# 7       Đường Khuê Mỹ Đông 15, Phường Mỹ An, Quận Ngũ...   13,5 tỷ    110 m2
# 8       Đường Dương Vân Nga, Phường Nại Hiên Đông, Qu...   14,4 tỷ    130 m2
# ...                                                  ...        ...      ...
# 14927   52 Đường Trần Can, Phường Hòa Khê, Quận Thanh...    5,7 tỷ     85 m2
# 14931   Đường Lê Văn Hưu, Phường Mỹ An, Quận Ngũ Hành...   12,5 tỷ    138 m2
# 14935   Đường Hoài Thanh, Phường Mỹ An, Quận Ngũ Hành...     14 tỷ    160 m2
# 14936   Đường Nguyễn Thị Định, Phường An Hải Bắc, Quậ...    9,5 tỷ     90 m2
# 14940   Đường Hoàng Văn Thái, Phường Hòa Khánh Nam, Q...   2,99 tỷ     70 m2
#
# ...
